# %%
import pandas as pd
df = pd.read_csv("/content/advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
X = df[["TV" , "Radio", "Newspaper"]]

# %%
Y = df[["Sales"]]

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
Y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2     12.0
# 3     16.5
# 4     17.9
# ..     ...
# 195    7.6
# 196   14.0
# 197   14.8
# 198   25.5
# 199   18.4
#
# [200 rows x 1 columns]

# %%
import pandas as pd

df = pd.read_csv("/content/student_performance.csv")

# %%
df
# Out:
#        student_id  weekly_self_study_hours  attendance_percentage  \
# 0               1                     18.5                   95.6
# 1               2                     14.0                   80.0
# 2               3                     19.5                   86.3
# 3               4                     25.7                   70.2
# 4               5                     13.4                   81.9
# ...           ...                      ...                    ...
# 39752       39753                      6.7                   88.6
# 39753       39754                     19.3                   88.5
# 39754       39755                      7.3                   83.0
# 39755       39756                     19.5                   89.2
# 39756       39757                     26.9                   67.1
#
#        class_participation  total_score grade
# 0                      3.8         97.9     A
# 1                      2.5         83.9     B
# 2                      5.3        100.0     A
# 3                      7.0        100.0     A
# 4                      6.9         92.0     A
# ...                    ...          ...   ...
# 39752                  4.9         64.3     C
# 39753                  5.0        100.0     A
# 39754                  8.3         67.8     C
# 39755                  4.9         94.7     A
# 39756                  7.9        100.0   NaN
#
# [39757 rows x 6 columns]

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.shape
# Out:
# (39757, 6)

# %%
df.describe()
# Out:
#          student_id  weekly_self_study_hours  attendance_percentage  \
# count  39757.000000             39757.000000           39757.000000
# mean   19879.000000                15.019134              84.670642
# std    11477.001663                 6.894944               9.433475
# min        1.000000                 0.000000              50.000000
# 25%     9940.000000                10.200000              78.300000
# 50%    19879.000000                15.000000              84.900000
# 75%    29818.000000                19.700000              91.700000
# max    39757.000000                40.000000             100.000000
#
#        class_participation   total_score
# count         39757.000000  39757.000000
# mean              5.987924     84.262993
# std               1.956663     15.421120
# min               0.000000     14.600000
# 25%               4.700000     73.900000
# 50%               6.000000     87.400000
# 75%               7.400000    100.000000
# max              10.000000    100.000000

# %%
df.isnull().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      1
# dtype: int64

# %%
df
# Out:
#        student_id  weekly_self_study_hours  attendance_percentage  \
# 0               1                     18.5                   95.6
# 1               2                     14.0                   80.0
# 2               3                     19.5                   86.3
# 3               4                     25.7                   70.2
# 4               5                     13.4                   81.9
# ...           ...                      ...                    ...
# 39752       39753                      6.7                   88.6
# 39753       39754                     19.3                   88.5
# 39754       39755                      7.3                   83.0
# 39755       39756                     19.5                   89.2
# 39756       39757                     26.9                   67.1
#
#        class_participation  total_score grade
# 0                      3.8         97.9     A
# 1                      2.5         83.9     B
# 2                      5.3        100.0     A
# 3                      7.0        100.0     A
# 4                      6.9         92.0     A
# ...                    ...          ...   ...
# 39752                  4.9         64.3     C
# 39753                  5.0        100.0     A
# 39754                  8.3         67.8     C
# 39755                  4.9         94.7     A
# 39756                  7.9        100.0   NaN
#
# [39757 rows x 6 columns]

# %%
df_sample = df.sample(n = 5000 , random_state = 7)

# %%
df_sample.shape[0]
# Out:
# 5000

# %%
import matplotlib.pyplot as plt
plt.scatter(df_sample["weekly_self_study_hours"], df_sample["total_score"], alpha = 0.5)
plt.title("weekly_self_study_hours vs total_score")
plt.xlabel("weekly_self_study_hours")
plt.ylabel("total_score")
plt.grid(True)
plt.show()

# %%
X = df_sample[["weekly_self_study_hours"]]
Y = df_sample[["total_score"]]

# %%
X
# Out:
#        weekly_self_study_hours
# 37193                     18.5
# 25344                     28.0
# 11902                      0.0
# 30068                     31.0
# 11899                     22.3
# ...                        ...
# 21691                     21.8
# 30832                     19.3
# 25784                     10.9
# 39418                     14.1
# 30044                      9.0
#
# [5000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
X_test
# Out:
#        weekly_self_study_hours
# 11835                     15.1
# 7731                      16.7
# 22235                     11.1
# 25409                      8.2
# 20735                     13.7
# ...                        ...
# 38096                     12.5
# 38441                     23.3
# 28430                      0.9
# 28898                      8.7
# 27727                     18.9
#
# [1000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]
intercept = model.intercept_

# %%
slope
# Out:
# array([1.82058151])

# %%
intercept
# Out:
# array([56.73725469])

# %%
y_pred = model.predict(X_test)

comparison = pd.DataFrame({"Actual Score": Y_test[:10].values.flatten(), "Predicted Score" : y_pred[:10].flatten()})

# %%
comparison
# Out:
#    Actual Score  Predicted Score
# 0          94.7        84.228036
# 1          86.1        87.140966
# 2          68.9        76.945710
# 3          63.9        71.666023
# 4          84.8        81.679221
# 5          85.6        84.774210
# 6          44.8        62.198999
# 7          75.1        78.220117
# 8          79.9        71.666023
# 9          72.4        69.117209

# %%
from sklearn.metrics import r2_score

r2 = r2_score(Y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.6786740876615089

# %%
plt.scatter(X_train , Y_train , alpha = 0.3 , color = "blue" , label = "Training Data")
plt.plot(X_train , model.predict(X_train) , color = "red" , label = "Best-Fit line")

plt.title("Simple Linear Regression")
plt.xlabel("Weekly Self Study Hours")
plt.ylabel("Total Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 6.961988017154442

# %%
# Step 1 - Import all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# Step 2 = Loading the Data

df = pd.read_csv("/content/student_performance.csv")

# %%
# Step 3 - Taking a sample of 5000 students

df_sample = df.sample(n = 5000 , random_state = 7)

# %%
df_sample
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 125051      125052                      8.1                   85.0
# 75979        75980                     16.9                   97.9
# 33809        33810                     11.7                   83.9
# 77968        77969                      3.8                   89.4
# 121468      121469                     14.0                   70.6
# ...            ...                      ...                    ...
# 120910      120911                     11.7                   71.1
# 22424        22425                      7.5                   86.9
# 149479      149480                      9.8                   96.4
# 147333      147334                     16.3                   72.3
# 73872        73873                     21.9                   75.6
#
#         class_participation  total_score grade
# 125051                  5.2         66.2     C
# 75979                  10.0         87.5     A
# 33809                   6.3         62.4     C
# 77968                   4.2         78.2     B
# 121468                  9.0         78.3     B
# ...                     ...          ...   ...
# 120910                  9.7         72.3     B
# 22424                   4.0         75.9     B
# 149479                  5.3         60.9     C
# 147333                  6.7         97.6     A
# 73872                   7.3        100.0     A
#
# [5000 rows x 6 columns]

# %%
# Step 4 - Use all 3 Features

features = ["weekly_self_study_hours", "attendance_percentage", "class_participation"]

x = df_sample[features]

# %%
x
# Out:
#         weekly_self_study_hours  attendance_percentage  class_participation
# 125051                      8.1                   85.0                  5.2
# 75979                      16.9                   97.9                 10.0
# 33809                      11.7                   83.9                  6.3
# 77968                       3.8                   89.4                  4.2
# 121468                     14.0                   70.6                  9.0
# ...                         ...                    ...                  ...
# 120910                     11.7                   71.1                  9.7
# 22424                       7.5                   86.9                  4.0
# 149479                      9.8                   96.4                  5.3
# 147333                     16.3                   72.3                  6.7
# 73872                      21.9                   75.6                  7.3
#
# [5000 rows x 3 columns]

# %%
y = df_sample["total_score"]
y
# Out:
# 125051     66.2
# 75979      87.5
# 33809      62.4
# 77968      78.2
# 121468     78.3
#           ...
# 120910     72.3
# 22424      75.9
# 149479     60.9
# 147333     97.6
# 73872     100.0
# Name: total_score, Length: 5000, dtype: float64

# %%
# Step 5 - Splitting the Data Training 80% - Testing 20%

x_train , x_test , y_train , y_test = train_test_split(x, y , test_size = 0.2 , random_state = 42)

# %%
# Step 6 - Training the Model

model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
coefficients = model.coef_
intercept = model.intercept_

# %%
x
# Out:
#         weekly_self_study_hours  attendance_percentage  class_participation
# 125051                      8.1                   85.0                  5.2
# 75979                      16.9                   97.9                 10.0
# 33809                      11.7                   83.9                  6.3
# 77968                       3.8                   89.4                  4.2
# 121468                     14.0                   70.6                  9.0
# ...                         ...                    ...                  ...
# 120910                     11.7                   71.1                  9.7
# 22424                       7.5                   86.9                  4.0
# 149479                      9.8                   96.4                  5.3
# 147333                     16.3                   72.3                  6.7
# 73872                      21.9                   75.6                  7.3
#
# [5000 rows x 3 columns]

# %%
coefficients
# Out:
# array([ 1.8466367 ,  0.00495878, -0.049075  ])

# %%
intercept
# Out:
# np.float64(56.42872195477182)

# %%
# Step 7 - Predict and Test the model

y_pred = model.predict(x_test)

compare = pd.DataFrame({"Actual Score": y_test[:10].values.flatten(), "Predicted Score" : y_pred[:10].flatten()})

# %%
compare
# Out:
#    Actual Score  Predicted Score
# 0         100.0       102.885617
# 1         100.0        87.670490
# 2          80.0        78.664334
# 3          73.8        78.116840
# 4         100.0       101.491949
# 5         100.0        96.583207
# 6         100.0        89.175312
# 7          82.1        73.304351
# 8          72.1        70.174396
# 9          62.2        73.023700

# %%
comparison
# Out:
#    Actual Score  Predicted Score
# 0          94.7        84.228036
# 1          86.1        87.140966
# 2          68.9        76.945710
# 3          63.9        71.666023
# 4          84.8        81.679221
# 5          85.6        84.774210
# 6          44.8        62.198999
# 7          75.1        78.220117
# 8          79.9        71.666023
# 9          72.4        69.117209

# %%
r2 = r2_score(y_test , y_pred)

# %%
r2
# Out:
# 0.6696828535726529

# %%
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 7.136201366555919

# %%
import pandas as pd
df = pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# Logistic Regression model and Decision Tree

# Step 1 - Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
# Loading the Dataset
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Step 3 Prepare the Data
X = df[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
Y = df[["Species"]]

# %%
Y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
# Split the data into train and test

X_train , X_test , Y_train , Y_test = train_test_split(X  , Y , test_size = 0.2 , random_state = 6)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
# Create the Logistic Regression model

log_reg = LogisticRegression(max_iter = 100)

log_reg.fit(X_train , Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Decision Tree model

tree_model = DecisionTreeClassifier()

tree_model.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predictions using both models

y_pred_log = log_reg.predict(X_test)

y_pred_tree = tree_model.predict(X_test)

# %%
# accuracy_log = log_reg.score(X_test , Y_test)
# accuracy_tree = tree_model.score(X_test , Y_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_log = accuracy_score(Y_test , y_pred_log)
accuracy_tree = accuracy_score(Y_test , y_pred_tree)

# %%
print("Model Comparision")
print(f"Logistic Regression Accuracy : {accuracy_log * 100:.2f}%")
print(f"Decision Tree Accuracy : {accuracy_tree * 100:.2f}%")
# Out:
# Model Comparision
# Logistic Regression Accuracy : 96.67%
# Decision Tree Accuracy : 93.33%

# %%
from sklearn.metrics import classification_report
print("Detailed Report")
print(classification_report(Y_test , y_pred_log , target_names = ["Iris-setosa" , "Iris-versicolor" , "Iris-virginica"]))
# Out:
# Detailed Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.91      0.95        11
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30
